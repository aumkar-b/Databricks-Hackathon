# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# We'll use the `Phi-3` format for conversational finetunes. We use the [Open Assistant dataset](https://huggingface.co/datasets/philschmid/guanaco-sharegpt-style) in ShareGPT style.

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %% [markdown]
# * We support Llama, Mistral, Phi-3, Gemma, Yi, DeepSeek, Qwen, TinyLlama, Vicuna, Open Hermes etc
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.
# * [**NEW**] We make Llama-3 15 trillion tokens **2x faster**! See our [Llama-3 notebook](https://colab.research.google.com/drive/135ced7oHytdxu3N2DNe1Z0kqjyYIkDXp?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-v0.3-bnb-4bit",      # New Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/llama-3-8b-bnb-4bit",           # Llama-3 15 trillion tokens model 2x faster!
    "unsloth/llama-3-8b-Instruct-bnb-4bit",
    "unsloth/llama-3-70b-bnb-4bit",
    "unsloth/Phi-3-mini-4k-instruct",        # Phi-3 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",             # Gemma 2.2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-3-medium-4k-instruct", # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.1.5: Fast Mistral patching. Transformers: 4.47.1.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/165k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.72G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/458 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.1.5 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Phi-3` format for conversation style finetunes. We use [Open Assistant conversations](https://huggingface.co/datasets/philschmid/guanaco-sharegpt-style) in ShareGPT style. Phi-3 renders multi turn conversations like below:
#
# ```
# <s><|user|>
# Hi!<|end|>
# <|assistant|>
# Hello! How are you?<|end|>
# <|user|>
# I'm doing great! And you?<|end|>
#
# ```
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old` and our own optimized `unsloth` template.
#
# Note ShareGPT uses `{"from": "human", "value" : "Hi"}` and not `{"role": "user", "content" : "Hi"}`, so we use `mapping` to map it.
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
)


def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [
        tokenizer.apply_chat_template(
            [{"role": "user", "content": convo}],  # Wrap convo in a list of dicts
            tokenize=False,
            add_generation_prompt=False
        )
        for convo in convos
    ]
    return {"text": texts}

pass

from datasets import load_dataset
dataset = load_dataset("aumkar24/testcase_finetuning", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/4735 [00:00<?, ? examples/s]

# %%
def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [
        tokenizer.apply_chat_template(
            [{"role": "user", "content": convo}],  # Wrap convo in a list of dicts
            tokenize=False,
            add_generation_prompt=False
        )
        for convo in convos
    ]
    return {"text": texts}

# %% [markdown]
# Let's see how the `Phi-3` format works by printing the 5th element

# %%
dataset[5]["conversations"]
# Out:
# '[{"from": "human", "value": "Test Cases for Updating Bio/About Section in a Social Networking App"}, {"from": "gpt", "value": "id: 6 test_case_id: TC_PROFILE_001 test_scenario: Verify that a user can successfully update their bio/about section. test_steps: 1. Log in to the social networking app.\\n2. Navigate to the profile section.\\n3. Click on the edit bio/about section.\\n4. Update the bio/about information.\\n5. Save the changes. expected_intended_result: The user\'s bio/about section is updated successfully. pass_fail_criteria: The updated bio information should be displayed in the user\'s profile."}]'

# %%
print(dataset[5]["text"])
# Out:
# <|user|>
# [{"from": "human", "value": "Test Cases for Updating Bio/About Section in a Social Networking App"}, {"from": "gpt", "value": "id: 6 test_case_id: TC_PROFILE_001 test_scenario: Verify that a user can successfully update their bio/about section. test_steps: 1. Log in to the social networking app.\n2. Navigate to the profile section.\n3. Click on the edit bio/about section.\n4. Update the bio/about information.\n5. Save the changes. expected_intended_result: The user's bio/about section is updated successfully. pass_fail_criteria: The updated bio information should be displayed in the user's profile."}]<|end|>

# %% [markdown]
# If you're looking to make your own chat template, that also is possible! You must use the Jinja templating regime. We provide our own stripped down version of the `Unsloth template` which we find to be more efficient, and leverages ChatML, Zephyr and Alpaca styles.
#
# More info on chat templates on [our wiki page!](https://github.com/unslothai/unsloth/wiki#chat-templates)

# %%
unsloth_template = \
    "{{ bos_token }}"\
    "{{ 'You are a helpful assistant to the user\n' }}"\
    "{% for message in messages %}"\
        "{% if message['role'] == 'user' %}"\
            "{{ '>>> User: ' + message['content'] + '\n' }}"\
        "{% elif message['role'] == 'assistant' %}"\
            "{{ '>>> Assistant: ' + message['content'] + eos_token + '\n' }}"\
        "{% endif %}"\
    "{% endfor %}"\
    "{% if add_generation_prompt %}"\
        "{{ '>>> Assistant: ' }}"\
    "{% endif %}"
unsloth_eos_token = "eos_token"

if False:
    tokenizer = get_chat_template(
        tokenizer,
        chat_template = (unsloth_template, unsloth_eos_token,), # You must provide a template and EOS token
        mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
        map_eos_token = True, # Maps <|im_end|> to </s> instead
    )

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/4735 [00:00<?, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 7.504 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 4,735 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 60
#  "-____-"     Number of trainable parameters = 65,536,000
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 11:21, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.733000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.747800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.746700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.752200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.463900</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.531300</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.439600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.236500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.093400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.026900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.943200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.802700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.815400</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.839600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.829500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.822000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.786400</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.748000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.783700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.606800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.719300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.771300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.749200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.685800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.713800</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.641400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.706600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.622500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.712100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.686300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.605900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.606600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.608700</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.699100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.686000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.682200</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.688000</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.624700</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.638800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.622600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.573700</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.704200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.662800</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.607400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.665300</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.644400</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.637200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.691900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.620200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.716500</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.616500</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.621700</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.613400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.608200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.603900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.626500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.615200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.707900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.596900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.655000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 703.3888 seconds used for training.
# 11.72 minutes used for training.
# Peak reserved memory = 8.514 GB.
# Peak reserved memory for training = 1.01 GB.
# Peak reserved memory % of max memory = 57.73 %.
# Peak reserved memory for training % of max memory = 6.848 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! Since we're using `Phi-3`, use `apply_chat_template` with `add_generation_prompt` set to `True` for inference.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
)

FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "write multiple testcase for testing flipkart login"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

outputs = model.generate(input_ids = inputs, max_new_tokens = 1084, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|user|> write multiple testcase for testing flipkart login<|end|><|assistant|> Test Case 1: Verify that a user can successfully log in with valid credentials\n- Test Scenario: User enters valid username and password.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter valid username and password.\n  3. Click on the "Login" button.\n- Expected Intended Result: User should be successfully logged in and redirected to the homepage.\n- Pass/Fail Criteria: Test passes if the user is logged in successfully; otherwise, it fails.\n\nTest Case 2: Verify that the system displays an error message for invalid username\n- Test Scenario: User enters an invalid username.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter an invalid username and valid password.\n  3. Click on the "Login" button.\n- Expected Intended Result: System should display an error message indicating that the username is invalid.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.\n\nTest Case 3: Verify that the system displays an error message for invalid password\n- Test Scenario: User enters a valid username and an invalid password.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter a valid username and an invalid password.\n  3. Click on the "Login" button.\n- Expected Intended Result: System should display an error message indicating that the password is invalid.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.\n\nTest Case 4: Verify that the system displays an error message for blank username and password fields\n- Test Scenario: User leaves both username and password fields blank.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Leave both username and password fields blank.\n  3. Click on the "Login" button.\n- Expected Intended Result: System should display an error message indicating that both fields are required.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.\n\nTest Case 5: Verify that the system displays an error message for a locked account\n- Test Scenario: User attempts to log in with a locked account.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter a username and password for a locked account.\n  3. Click on the "Login" button.\n- Expected Intended Result: System should display an error message indicating that the account is locked.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.\n\nTest Case 6: Verify that the system displays an error message for a two-factor authentication failure\n- Test Scenario: User fails to complete two-factor authentication.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter valid username and password.\n  3. Click on the "Login" button.\n  4. Fail to complete two-factor authentication.\n- Expected Intended Result: System should display an error message indicating that two-factor authentication failed.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.\n\nTest Case 7: Verify that the system displays an error message for a network connectivity issue\n- Test Scenario: User experiences a network connectivity issue while logging in.\n- Test Steps:\n  1. Navigate to the Flipkart login page.\n  2. Enter valid username and password.\n  3. Click on the "Login" button.\n  4. Simulate a network connectivity issue.\n- Expected Intended Result: System should display an error message indicating that there is a network connectivity issue.\n- Pass/Fail Criteria: Test passes if the error message is displayed; otherwise, it fails.<|end|>']

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "write multiple testcase for testing flipkart product listing"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 1084, use_cache = True)
# Out:
# <|user|> write multiple testcase for testing flipkart product listing<|end|><|assistant|> Test Case 1: Verify that a product can be added to the Flipkart listing.
#
# Test Steps:
# 1. Login to the Flipkart seller account.
# 2. Navigate to the "Add Product" section.
# 3. Enter the product details (name, description, price, etc.).
# 4. Upload product images.
# 5. Click on "Save" or "Submit" button.
#
# Expected Intended Result:
# The product should be successfully added to the Flipkart listing.
#
# Pass/Fail Criteria:
# The test will pass if the product is successfully added to the listing. The test will fail if the product is not added or if there is an error during the process.
#
# Test Case 2: Verify that a product can be edited in the Flipkart listing.
#
# Test Steps:
# 1. Login to the Flipkart seller account.
# 2. Navigate to the "Product Listings" section.
# 3. Select a product to edit.
# 4. Update the product details (name, description, price, etc.).
# 5. Click on "Save" or "Update" button.
#
# Expected Intended Result:
# The product details should be successfully updated in the Flipkart listing.
#
# Pass/Fail Criteria:
# The test will pass if the product details are successfully updated. The test will fail if the product details are not updated or if there is an error during the process.
#
# Test Case 3: Verify that a product can be removed from the Flipkart listing.
#
# Test Steps:
# 1. Login to the Flipkart seller account.
# 2. Navigate to the "Product Listings" section.
# 3. Select a product to remove.
# 4. Click on "Delete" or "Remove" button.
#
# Expected Intended Result:
# The product should be successfully removed from the Flipkart listing.
#
# Pass/Fail Criteria:
# The test will pass if the product is successfully removed from the listing. The test will fail if the product is not removed or if there is an error during the process.
#
# Test Case 4: Verify that a product's stock quantity can be updated in the Flipkart listing.
#
# Test Steps:
# 1. Login to the Flipkart seller account.
# 2. Navigate to the "Product Listings" section.
# 3. Select a product to update stock quantity.
# 4. Update the stock quantity.
# 5. Click on "Save" or "Update" button.
#
# Expected Intended Result:
# The product's stock quantity should be successfully updated in the Flipkart listing.
#
# Pass/Fail Criteria:
# The test will pass if the stock quantity is successfully updated. The test will fail if the stock quantity is not updated or if there is an error during the process.
#
# Test Case 5: Verify that a product's availability status can be updated in the Flipkart listing.
#
# Test Steps:
# 1. Login to the Flipkart seller account.
# 2. Navigate to the "Product Listings" section.
# 3. Select a product to update availability status.
# 4. Update the availability status (In Stock, Out of Stock, etc.).
# 5. Click on "Save" or "Update" button.
#
# Expected Intended Result:
# The product's availability status should be successfully updated in the Flipkart listing.
#
# Pass/Fail Criteria:
# The test will pass if the availability status is successfully updated. The test will fail if the availability status is not updated or if there is an error during the process.<|end|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
# model.save_pretrained("lora_model") # Local saving
model.push_to_hub("aumkar24/lora_model", token = "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")
# Out:
# README.md:   0%|          | 0.00/607 [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/262M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/aumkar24/lora_model

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "What is a famous tall tower in Paris?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128, use_cache = True)
# Out:
# <s><|user|> What is a famous tall tower in Paris?<|end|><|assistant|> The Eiffel Tower is a famous tall tower in Paris.<|end|>

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoModelForPeftCausalLM
    from transformers import AutoTokenizer
    model = AutoModelForPeftCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
# 9. Gemma 6 trillion tokens is 2.5x faster! [free Colab](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
